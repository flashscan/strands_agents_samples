# %% [markdown]
# # Advanced processing of Strands Agents Response

# %% [markdown]
# Strands Agents allows you to intercept and process events as they happen during agent execution using two methods:
#
# - **Async iterators**: ideal for asynchronous frameworks like FastAPI, aiohttp, or Django Channels. For these environments, the SDK offers the `stream_async` method which returns an asynchronous iterator.
# - **Callback handlers**: allow you to intercept and process events as they happen during agent execution. This enables real-time monitoring, custom output formatting, and integration with external systems.
#
# In this example, we will show you how to use both methods to handle calls on your agent
#
#
# ## Agent Details
# <div style="float: left; margin-right: 20px; ">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Feature used        |async iterators, callback handlers                 |
# |Agent Structure     |single agent architecture                          |
# |Native tools used   |calculator                                         |
# |Custom tools created|Weather forecast                                   |
#
# </div>

# %% [markdown]
# ## Architecture
#
# <div style="text-align:left;">
#     <img src="images/architecture.png" width="65%" />
# </div>
#
# ## Key Features
# * Async Iterators for Streaming
# * Callback Handlers
#
#
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * AWS account
# * Anthropic Claude Sonnet 4.5 enabled on Amazon Bedrock
#
# Let's now install the requirement packages for our Strands Agent Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Collecting fastapi
#   Downloading fastapi-0.136.1-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: uv in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.11.7)
# Requirement already satisfied: strands-agents in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.37.0)
# Requirement already satisfied: strands-agents-tools in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: uvicorn in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.46.0)
# Requirement already satisfied: pydantic in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.13.3)
# Requirement already satisfied: nest_asyncio in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: starlette>=0.46.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from fastapi->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from fastapi->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from fastapi->-r requirements.txt (line 1)) (0.4.2)
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (0.62b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (1.41.0)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (1.42.94)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (1.42.94)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (1.27.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (4.26.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 3)) (1.41.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (14.3.4)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (2.12.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (9.1.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (3.13.5)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (12.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (1.28.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (1.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 4)) (2.33.1)
# Requirement already satisfied: click>=7.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from uvicorn->-r requirements.txt (line 5)) (8.3.3)
# Requirement already satisfied: h11>=0.8 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from uvicorn->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic->-r requirements.txt (line 6)) (2.46.3)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (1.23.0)
# Requirement already satisfied: propcache>=0.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 3)) (0.16.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 3)) (2.6.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: referencing>=0.28.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: six<2,>=1.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 4)) (4.14.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (0.0.26)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: httpx-sse>=0.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: anyio>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (4.13.0)
# Requirement already satisfied: sse-starlette>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (3.3.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 3)) (8.7.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 3)) (0.62b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 3)) (0.62b0)
# Requirement already satisfied: packaging>=18.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 3)) (26.1)
# Requirement already satisfied: wcwidth in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 4)) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 4)) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 4)) (3.41.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 4)) (2.8.3)
# Requirement already satisfied: httpcore==1.* in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 3)) (3.23.1)
# Requirement already satisfied: mdurl~=0.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 4)) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: pycparser in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 4)) (3.0)
# Installing collected packages: annotated-doc, fastapi
# Successfully installed annotated-doc-0.0.4 fastapi-0.136.1

# %% [markdown]
# ### Importing dependency packages
#
# Now let's import the dependency packages

# %%
import asyncio

import httpx
import nest_asyncio
import uvicorn
from fastapi import FastAPI
from fastapi.responses import StreamingResponse
from pydantic import BaseModel
from strands import Agent, tool
from strands_tools import calculator

# %% [markdown]
# ## Method 1 - Async Iterators for Streaming

# %% [markdown]
# Strands Agents provides support for asynchronous iterators through the `stream_async` method, enabling real-time streaming of agent responses in asynchronous environments like web servers, APIs, and other async applications.
#
# Since we are show casing this example in a notebook, we need to apply `nest_asyncio` to allow nested use of `asyncio.run` and `loop.run_until_complete`

# %%
nest_asyncio.apply()

# %% [markdown]
# ### Creating and invoking agent with stream_async
#
# Let's now create our agent with a built-in calculator tool and no `callback_handler`. We will use the `stream_async` method to iteract over the streamed agent events

# %%
# Initialize our agent without a callback handler
agent = Agent(
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
    tools=[calculator], 
    callback_handler=None)

# Async function that iterators over streamed agent events


async def process_streaming_response():
    agent_stream = agent.stream_async("Calculate 2+2")
    async for event in agent_stream:
        print(event)


# Run the agent
asyncio.run(process_streaming_response())
# Out:
# {'init_event_loop': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockStart': {'start': {'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'type': 'tool_use'}}, 'contentBlockIndex': 0}}}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': ''}}, 'contentBlockIndex': 0}}}
# {'type': 'tool_use_stream', 'delta': {'toolUse': {'input': ''}}, 'current_tool_use': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': ''}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('e0ba010f-691a-4400-a88c-44b60f6fed13'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61720>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '{"'}}, 'contentBlockIndex': 0}}}
# {'type': 'tool_use_stream', 'delta': {'toolUse': {'input': '{"'}}, 'current_tool_use': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': '{"'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('e0ba010f-691a-4400-a88c-44b60f6fed13'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61720>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'expressi'}}, 'contentBlockIndex': 0}}}
# {'type': 'tool_use_stream', 'delta': {'toolUse': {'input': 'expressi'}}, 'current_tool_use': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': '{"expressi'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('e0ba010f-691a-4400-a88c-44b60f6fed13'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61720>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': 'on": '}}, 'contentBlockIndex': 0}}}
# {'type': 'tool_use_stream', 'delta': {'toolUse': {'input': 'on": '}}, 'current_tool_use': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': '{"expression": '}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('e0ba010f-691a-4400-a88c-44b60f6fed13'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61720>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False))}
# {'event': {'contentBlockDelta': {'delta': {'toolUse': {'input': '"2+2"}'}}, 'contentBlockIndex': 0}}}
# {'type': 'tool_use_stream', 'delta': {'toolUse': {'input': '"2+2"}'}}, 'current_tool_use': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': '{"expression": "2+2"}'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('e0ba010f-691a-4400-a88c-44b60f6fed13'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61720>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False))}
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'messageStop': {'stopReason': 'tool_use'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513}}}}
# {'message': {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}}
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 2+2                 │                                                                            │
# │  │ Result    │ 4                   │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'message': {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}}
# {'start': True}
# {'start': True}
# {'start_event_loop': True}
# {'event': {'messageStart': {'role': 'assistant'}}}
# {'event': {'contentBlockDelta': {'delta': {'text': 'The result'}, 'contentBlockIndex': 0}}}
# {'data': 'The result', 'delta': {'text': 'The result'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('11d98e64-15fc-4868-a2ee-84ad2ed1729a'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff68139060>, 'messages': [{'role': 'user', 'content': [{'text': 'Calculate 2+2'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}, {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}], 'system_prompt': None, 'tool_config': {'tools': [{'toolSpec': {'name': 'calculator', 'description': 'Calculator powered by SymPy for comprehensive mathematical operations.\n\nThis tool provides advanced mathematical functionality through multiple operation modes,\nincluding expression evaluation, equation solving, calculus operations (derivatives, integrals),\nlimits, series expansions, and matrix operations. Results are formatted with appropriate\nprecision and can be displayed in scientific notation when needed.\n\nHow It Works:\n------------\n1. The function parses the mathematical expression using SymPy\'s parser\n2. Based on the selected mode, it routes the expression to the appropriate handler\n3. Variables and constants are substituted with their values when provided\n4. The expression is evaluated symbolically and/or numerically as appropriate\n5. Results are formatted based on precision preferences and value magnitude\n6. Rich output is generated with operation details and formatted results\n\nOperation Modes:\n--------------\n- evaluate: Calculate the value of a mathematical expression\n- solve: Find solutions to an equation or system of equations\n- derive: Calculate derivatives of an expression\n- integrate: Find the indefinite integral of an expression\n- limit: Evaluate the limit of an expression at a point\n- series: Generate series expansion of an expression\n- matrix: Perform matrix operations\n\nCommon Usage Scenarios:\n---------------------\n- Basic calculations: Evaluating arithmetic expressions\n- Equation solving: Finding roots of polynomials or systems of equations\n- Calculus: Computing derivatives and integrals for analysis\n- Engineering analysis: Working with scientific notations and constants\n- Mathematics education: Visualizing step-by-step solutions\n- Data science: Matrix operations and statistical calculations\n\nReturns:\n    Dict containing status and response content in the format:\n    {\n        "status": "success|error",\n        "content": [{"text": "Result: <calculated_result>"}]\n    }\n\n    Success case: Returns the calculation result with appropriate formatting\n    Error case: Returns information about what went wrong during calculation\n\nNotes:\n    - For equation solving, set the expression equal to zero implicitly (x**2 + 1 means x**2 + 1 = 0)\n    - Use \'pi\' and \'e\' for mathematical constants\n    - The \'wrt\' parameter is required for differentiation and integration\n    - Matrix expressions use Python-like syntax: [[1, 2], [3, 4]]\n    - Precision control impacts display only, internal calculations use higher precision\n    - Symbolic results are returned when possible unless force_numeric=True', 'inputSchema': {'json': {'properties': {'expression': {'description': 'The mathematical expression to evaluate, such as "2 + 2 * 3",\n"x**2 + 2*x + 1", or "sin(pi/2)". For matrix operations, use array\nnotation like "[[1, 2], [ ...
# {'event': {'contentBlockDelta': {'delta': {'text': ' of'}, 'contentBlockIndex': 0}}}
# {'data': ' of', 'delta': {'text': ' of'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('11d98e64-15fc-4868-a2ee-84ad2ed1729a'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff68139060>, 'messages': [{'role': 'user', 'content': [{'text': 'Calculate 2+2'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}, {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}], 'system_prompt': None, 'tool_config': {'tools': [{'toolSpec': {'name': 'calculator', 'description': 'Calculator powered by SymPy for comprehensive mathematical operations.\n\nThis tool provides advanced mathematical functionality through multiple operation modes,\nincluding expression evaluation, equation solving, calculus operations (derivatives, integrals),\nlimits, series expansions, and matrix operations. Results are formatted with appropriate\nprecision and can be displayed in scientific notation when needed.\n\nHow It Works:\n------------\n1. The function parses the mathematical expression using SymPy\'s parser\n2. Based on the selected mode, it routes the expression to the appropriate handler\n3. Variables and constants are substituted with their values when provided\n4. The expression is evaluated symbolically and/or numerically as appropriate\n5. Results are formatted based on precision preferences and value magnitude\n6. Rich output is generated with operation details and formatted results\n\nOperation Modes:\n--------------\n- evaluate: Calculate the value of a mathematical expression\n- solve: Find solutions to an equation or system of equations\n- derive: Calculate derivatives of an expression\n- integrate: Find the indefinite integral of an expression\n- limit: Evaluate the limit of an expression at a point\n- series: Generate series expansion of an expression\n- matrix: Perform matrix operations\n\nCommon Usage Scenarios:\n---------------------\n- Basic calculations: Evaluating arithmetic expressions\n- Equation solving: Finding roots of polynomials or systems of equations\n- Calculus: Computing derivatives and integrals for analysis\n- Engineering analysis: Working with scientific notations and constants\n- Mathematics education: Visualizing step-by-step solutions\n- Data science: Matrix operations and statistical calculations\n\nReturns:\n    Dict containing status and response content in the format:\n    {\n        "status": "success|error",\n        "content": [{"text": "Result: <calculated_result>"}]\n    }\n\n    Success case: Returns the calculation result with appropriate formatting\n    Error case: Returns information about what went wrong during calculation\n\nNotes:\n    - For equation solving, set the expression equal to zero implicitly (x**2 + 1 means x**2 + 1 = 0)\n    - Use \'pi\' and \'e\' for mathematical constants\n    - The \'wrt\' parameter is required for differentiation and integration\n    - Matrix expressions use Python-like syntax: [[1, 2], [3, 4]]\n    - Precision control impacts display only, internal calculations use higher precision\n    - Symbolic results are returned when possible unless force_numeric=True', 'inputSchema': {'json': {'properties': {'expression': {'description': 'The mathematical expression to evaluate, such as "2 + 2 * 3",\n"x**2 + 2*x + 1", or "sin(pi/2)". For matrix operations, use array\nnotation like "[[1, 2], [3, 4]]".', 'ty ...
# {'event': {'contentBlockDelta': {'delta': {'text': ' 2 '}, 'contentBlockIndex': 0}}}
# {'data': ' 2 ', 'delta': {'text': ' 2 '}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('11d98e64-15fc-4868-a2ee-84ad2ed1729a'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff68139060>, 'messages': [{'role': 'user', 'content': [{'text': 'Calculate 2+2'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}, {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}], 'system_prompt': None, 'tool_config': {'tools': [{'toolSpec': {'name': 'calculator', 'description': 'Calculator powered by SymPy for comprehensive mathematical operations.\n\nThis tool provides advanced mathematical functionality through multiple operation modes,\nincluding expression evaluation, equation solving, calculus operations (derivatives, integrals),\nlimits, series expansions, and matrix operations. Results are formatted with appropriate\nprecision and can be displayed in scientific notation when needed.\n\nHow It Works:\n------------\n1. The function parses the mathematical expression using SymPy\'s parser\n2. Based on the selected mode, it routes the expression to the appropriate handler\n3. Variables and constants are substituted with their values when provided\n4. The expression is evaluated symbolically and/or numerically as appropriate\n5. Results are formatted based on precision preferences and value magnitude\n6. Rich output is generated with operation details and formatted results\n\nOperation Modes:\n--------------\n- evaluate: Calculate the value of a mathematical expression\n- solve: Find solutions to an equation or system of equations\n- derive: Calculate derivatives of an expression\n- integrate: Find the indefinite integral of an expression\n- limit: Evaluate the limit of an expression at a point\n- series: Generate series expansion of an expression\n- matrix: Perform matrix operations\n\nCommon Usage Scenarios:\n---------------------\n- Basic calculations: Evaluating arithmetic expressions\n- Equation solving: Finding roots of polynomials or systems of equations\n- Calculus: Computing derivatives and integrals for analysis\n- Engineering analysis: Working with scientific notations and constants\n- Mathematics education: Visualizing step-by-step solutions\n- Data science: Matrix operations and statistical calculations\n\nReturns:\n    Dict containing status and response content in the format:\n    {\n        "status": "success|error",\n        "content": [{"text": "Result: <calculated_result>"}]\n    }\n\n    Success case: Returns the calculation result with appropriate formatting\n    Error case: Returns information about what went wrong during calculation\n\nNotes:\n    - For equation solving, set the expression equal to zero implicitly (x**2 + 1 means x**2 + 1 = 0)\n    - Use \'pi\' and \'e\' for mathematical constants\n    - The \'wrt\' parameter is required for differentiation and integration\n    - Matrix expressions use Python-like syntax: [[1, 2], [3, 4]]\n    - Precision control impacts display only, internal calculations use higher precision\n    - Symbolic results are returned when possible unless force_numeric=True', 'inputSchema': {'json': {'properties': {'expression': {'description': 'The mathematical expression to evaluate, such as "2 + 2 * 3",\n"x**2 + 2*x + 1", or "sin(pi/2)". For matrix operations, use array\nnotation like "[[1, 2], [3, 4]]".', 'ty ...
# {'event': {'contentBlockDelta': {'delta': {'text': '+ 2 is **'}, 'contentBlockIndex': 0}}}
# {'data': '+ 2 is **', 'delta': {'text': '+ 2 is **'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('11d98e64-15fc-4868-a2ee-84ad2ed1729a'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff68139060>, 'messages': [{'role': 'user', 'content': [{'text': 'Calculate 2+2'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}, {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}], 'system_prompt': None, 'tool_config': {'tools': [{'toolSpec': {'name': 'calculator', 'description': 'Calculator powered by SymPy for comprehensive mathematical operations.\n\nThis tool provides advanced mathematical functionality through multiple operation modes,\nincluding expression evaluation, equation solving, calculus operations (derivatives, integrals),\nlimits, series expansions, and matrix operations. Results are formatted with appropriate\nprecision and can be displayed in scientific notation when needed.\n\nHow It Works:\n------------\n1. The function parses the mathematical expression using SymPy\'s parser\n2. Based on the selected mode, it routes the expression to the appropriate handler\n3. Variables and constants are substituted with their values when provided\n4. The expression is evaluated symbolically and/or numerically as appropriate\n5. Results are formatted based on precision preferences and value magnitude\n6. Rich output is generated with operation details and formatted results\n\nOperation Modes:\n--------------\n- evaluate: Calculate the value of a mathematical expression\n- solve: Find solutions to an equation or system of equations\n- derive: Calculate derivatives of an expression\n- integrate: Find the indefinite integral of an expression\n- limit: Evaluate the limit of an expression at a point\n- series: Generate series expansion of an expression\n- matrix: Perform matrix operations\n\nCommon Usage Scenarios:\n---------------------\n- Basic calculations: Evaluating arithmetic expressions\n- Equation solving: Finding roots of polynomials or systems of equations\n- Calculus: Computing derivatives and integrals for analysis\n- Engineering analysis: Working with scientific notations and constants\n- Mathematics education: Visualizing step-by-step solutions\n- Data science: Matrix operations and statistical calculations\n\nReturns:\n    Dict containing status and response content in the format:\n    {\n        "status": "success|error",\n        "content": [{"text": "Result: <calculated_result>"}]\n    }\n\n    Success case: Returns the calculation result with appropriate formatting\n    Error case: Returns information about what went wrong during calculation\n\nNotes:\n    - For equation solving, set the expression equal to zero implicitly (x**2 + 1 means x**2 + 1 = 0)\n    - Use \'pi\' and \'e\' for mathematical constants\n    - The \'wrt\' parameter is required for differentiation and integration\n    - Matrix expressions use Python-like syntax: [[1, 2], [3, 4]]\n    - Precision control impacts display only, internal calculations use higher precision\n    - Symbolic results are returned when possible unless force_numeric=True', 'inputSchema': {'json': {'properties': {'expression': {'description': 'The mathematical expression to evaluate, such as "2 + 2 * 3",\n"x**2 + 2*x + 1", or "sin(pi/2)". For matrix operations, use array\nnotation like "[[1, 2], [3, ...
# {'event': {'contentBlockDelta': {'delta': {'text': '4**.'}, 'contentBlockIndex': 0}}}
# {'data': '4**.', 'delta': {'text': '4**.'}, 'agent': <strands.agent.agent.Agent object at 0xffff681391e0>, 'event_loop_cycle_id': UUID('11d98e64-15fc-4868-a2ee-84ad2ed1729a'), 'request_state': {}, 'event_loop_cycle_trace': <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, 'event_loop_cycle_span': NonRecordingSpan(SpanContext(trace_id=0x00000000000000000000000000000000, span_id=0x0000000000000000, trace_flags=0x00, trace_state=[], is_remote=False)), 'model': <strands.models.bedrock.BedrockModel object at 0xffff68139060>, 'messages': [{'role': 'user', 'content': [{'text': 'Calculate 2+2'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}}], 'metadata': {'usage': {'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}, 'metrics': {'latencyMs': 1513, 'timeToFirstByteMs': 1643}}}, {'role': 'user', 'content': [{'toolResult': {'status': 'success', 'content': [{'text': 'Result: 4'}], 'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf'}}]}], 'system_prompt': None, 'tool_config': {'tools': [{'toolSpec': {'name': 'calculator', 'description': 'Calculator powered by SymPy for comprehensive mathematical operations.\n\nThis tool provides advanced mathematical functionality through multiple operation modes,\nincluding expression evaluation, equation solving, calculus operations (derivatives, integrals),\nlimits, series expansions, and matrix operations. Results are formatted with appropriate\nprecision and can be displayed in scientific notation when needed.\n\nHow It Works:\n------------\n1. The function parses the mathematical expression using SymPy\'s parser\n2. Based on the selected mode, it routes the expression to the appropriate handler\n3. Variables and constants are substituted with their values when provided\n4. The expression is evaluated symbolically and/or numerically as appropriate\n5. Results are formatted based on precision preferences and value magnitude\n6. Rich output is generated with operation details and formatted results\n\nOperation Modes:\n--------------\n- evaluate: Calculate the value of a mathematical expression\n- solve: Find solutions to an equation or system of equations\n- derive: Calculate derivatives of an expression\n- integrate: Find the indefinite integral of an expression\n- limit: Evaluate the limit of an expression at a point\n- series: Generate series expansion of an expression\n- matrix: Perform matrix operations\n\nCommon Usage Scenarios:\n---------------------\n- Basic calculations: Evaluating arithmetic expressions\n- Equation solving: Finding roots of polynomials or systems of equations\n- Calculus: Computing derivatives and integrals for analysis\n- Engineering analysis: Working with scientific notations and constants\n- Mathematics education: Visualizing step-by-step solutions\n- Data science: Matrix operations and statistical calculations\n\nReturns:\n    Dict containing status and response content in the format:\n    {\n        "status": "success|error",\n        "content": [{"text": "Result: <calculated_result>"}]\n    }\n\n    Success case: Returns the calculation result with appropriate formatting\n    Error case: Returns information about what went wrong during calculation\n\nNotes:\n    - For equation solving, set the expression equal to zero implicitly (x**2 + 1 means x**2 + 1 = 0)\n    - Use \'pi\' and \'e\' for mathematical constants\n    - The \'wrt\' parameter is required for differentiation and integration\n    - Matrix expressions use Python-like syntax: [[1, 2], [3, 4]]\n    - Precision control impacts display only, internal calculations use higher precision\n    - Symbolic results are returned when possible unless force_numeric=True', 'inputSchema': {'json': {'properties': {'expression': {'description': 'The mathematical expression to evaluate, such as "2 + 2 * 3",\n"x**2 + 2*x + 1", or "sin(pi/2)". For matrix operations, use array\nnotation like "[[1, 2], [3, 4]]".', ' ...
# {'event': {'contentBlockStop': {'contentBlockIndex': 0}}}
# {'event': {'messageStop': {'stopReason': 'end_turn'}}}
# {'event': {'metadata': {'usage': {'inputTokens': 1763, 'outputTokens': 16, 'totalTokens': 1779}, 'metrics': {'latencyMs': 1366}}}}
# {'message': {'role': 'assistant', 'content': [{'text': 'The result of 2 + 2 is **4**.'}], 'metadata': {'usage': {'inputTokens': 1763, 'outputTokens': 16, 'totalTokens': 1779}, 'metrics': {'latencyMs': 1366, 'timeToFirstByteMs': 1090}}}}
# {'result': AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'The result of 2 + 2 is **4**.'}], 'metadata': {'usage': {'inputTokens': 1763, 'outputTokens': 16, 'totalTokens': 1779}, 'metrics': {'latencyMs': 1366, 'timeToFirstByteMs': 1090}}}, metrics=EventLoopMetrics(cycle_count=2, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_Ui5f3ak7z8pMwoqCnlGRcf', 'name': 'calculator', 'input': {'expression': '2+2'}}, call_count=1, success_count=1, error_count=0, total_time=0.040154218673706055)}, cycle_durations=[1.9536473751068115, 1.4664278030395508], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='e0ba010f-691a-4400-a88c-44b60f6fed13', usage={'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}), EventLoopCycleMetric(event_loop_cycle_id='11d98e64-15fc-4868-a2ee-84ad2ed1729a', usage={'inputTokens': 1763, 'outputTokens': 16, 'totalTokens': 1779})], usage={'inputTokens': 3456, 'outputTokens': 69, 'totalTokens': 3525})], traces=[<strands.telemetry.metrics.Trace object at 0xffff5de61720>, <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>], accumulated_usage={'inputTokens': 3456, 'outputTokens': 69, 'totalTokens': 3525}, accumulated_metrics={'latencyMs': 2879}), state={}, interrupts=None, structured_output=None)}

# %% [markdown]
# ###  Tracking event loop lifecycle

# %% [markdown]
# This example illustrates the event loop lifecycle and how events relate to each other. It's useful for understanding the flow of execution in the Strands Agent:
#
# Let's create some printing format code to better analyse the agent stream events. We will continue to use the same agent for it

# %%
# Async function that iterators over streamed agent events


async def process_streaming_response():
    agent_stream = agent.stream_async("What is the capital of France and what is 42+7?")
    async for event in agent_stream:
        # Track event loop lifecycle
        if event.get("init_event_loop", False):
            print("🔄 Event loop initialized")
        elif event.get("start_event_loop", False):
            print("▶️ Event loop cycle starting")
        elif event.get("start", False):
            print("📝 New cycle started")
        elif "message" in event:
            print(f"📬 New message created: {event['message']['role']}")
        elif event.get("force_stop", False):
            print(
                f"🛑 Event loop force-stopped: {event.get('force_stop_reason', 'unknown reason')}"
            )

        # Track tool usage
        if "current_tool_use" in event and event["current_tool_use"].get("name"):
            tool_name = event["current_tool_use"]["name"]
            print(f"🔧 Using tool: {tool_name}")

        # Show only a snippet of text to keep output clean
        if "data" in event:
            # Only show first 20 chars of each chunk for demo purposes
            data_snippet = event["data"][:20] + (
                "..." if len(event["data"]) > 20 else ""
            )
            print(f"📟 Text: {data_snippet}")

    return event["result"]


# Run the agent
asyncio.run(process_streaming_response())
# Out:
# 🔄 Event loop initialized
# 📝 New cycle started
# ▶️ Event loop cycle starting
# 🔧 Using tool: calculator
# 🔧 Using tool: calculator
# 🔧 Using tool: calculator
# 🔧 Using tool: calculator
# 📬 New message created: assistant
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 42+7                │                                                                            │
# │  │ Result    │ 49                  │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# 📬 New message created: user
# 📝 New cycle started
# 📝 New cycle started
# ▶️ Event loop cycle starting
# 📟 Text: The capital
# 📟 Text:  of France is **Pari...
# 📟 Text:
#
# And
# 📟 Text:  42 + 7 equals
# 📟 Text:  **49**.
# 📬 New message created: assistant
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'The capital of France is **Paris**.\n\nAnd 42 + 7 equals **49**.'}], 'metadata': {'usage': {'inputTokens': 1867, 'outputTokens': 24, 'totalTokens': 1891}, 'metrics': {'latencyMs': 1260, 'timeToFirstByteMs': 1043}}}, metrics=EventLoopMetrics(cycle_count=4, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_EKT1J0eDX3oMXObTDrt9mT', 'name': 'calculator', 'input': {'expression': '42+7'}}, call_count=2, success_count=2, error_count=0, total_time=0.0571141242980957)}, cycle_durations=[1.9536473751068115, 1.4664278030395508, 1.4641215801239014, 1.3587236404418945], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='e0ba010f-691a-4400-a88c-44b60f6fed13', usage={'inputTokens': 1693, 'outputTokens': 53, 'totalTokens': 1746}), EventLoopCycleMetric(event_loop_cycle_id='11d98e64-15fc-4868-a2ee-84ad2ed1729a', usage={'inputTokens': 1763, 'outputTokens': 16, 'totalTokens': 1779})], usage={'inputTokens': 3456, 'outputTokens': 69, 'totalTokens': 3525}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='43071bd3-31a3-47ff-86d8-66145cd842e8', usage={'inputTokens': 1797, 'outputTokens': 53, 'totalTokens': 1850}), EventLoopCycleMetric(event_loop_cycle_id='28be5227-a5d8-4e5c-ad1b-bcc7177d4562', usage={'inputTokens': 1867, 'outputTokens': 24, 'totalTokens': 1891})], usage={'inputTokens': 3664, 'outputTokens': 77, 'totalTokens': 3741})], traces=[<strands.telemetry.metrics.Trace object at 0xffff5de61720>, <strands.telemetry.metrics.Trace object at 0xffff5de61ab0>, <strands.telemetry.metrics.Trace object at 0xffff84606650>, <strands.telemetry.metrics.Trace object at 0xffff5de616f0>], accumulated_usage={'inputTokens': 7120, 'outputTokens': 146, 'totalTokens': 7266}, accumulated_metrics={'latencyMs': 5485}), state={}, interrupts=None, structured_output=None)

# %% [markdown]
# ### FastAPI Integration
#
# You can also integrate your `stream_async` with FastAPI to create a streaming endpoint to your applications. For this, we will add a `weather_forecast` tool to our agent. The architecture update looks as following
#
# <div style="text-align:left;">
#     <img src="images/architecture_2.png" width="65%" />
# </div>

# %%
# Tool definition


@tool
def weather_forecast(city: str, days: int = 3) -> str:
    return f"Weather forecast for {city} for the next {days} days..."


# FastAPI app
app = FastAPI()


class PromptRequest(BaseModel):
    prompt: str


@app.post("/stream")
async def stream_response(request: PromptRequest):
    async def generate():
        agent = Agent(tools=[calculator, weather_forecast], callback_handler=None)
        try:
            async for event in agent.stream_async(request.prompt):
                if "data" in event:
                    yield event["data"]
        except Exception as e:
            yield f"Error: {str(e)}"

    return StreamingResponse(generate(), media_type="text/plain")


# Function to start server without blocking


async def start_server():
    config = uvicorn.Config(app, host="0.0.0.0", port=8001, log_level="info")
    server = uvicorn.Server(config)
    await server.serve()


# Run server as background task
if "server_task" not in globals():
    server_task = asyncio.create_task(start_server())
    await asyncio.sleep(0.1)  # Give server time to start

print("✅ Server is running at http://0.0.0.0:8001")
# Out:
# INFO:     Started server process [263948]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8001 (Press CTRL+C to quit)
# ✅ Server is running at http://0.0.0.0:8001
# INFO:     127.0.0.1:59588 - "POST /stream HTTP/1.1" 200 OK

# %% [markdown]
# #### Invoking the FastAPI agent
# And we can now invoke the agent with a prompt

# %%
async def fetch_stream():
    async with httpx.AsyncClient(timeout=httpx.Timeout(45.0)) as client:
        async with client.stream(
            "POST",
            "http://0.0.0.0:8001/stream",
            json={"prompt": "What is weather in NYC?"},
        ) as response:
            async for line in response.aiter_lines():
                if line.strip():  # Skip empty lines
                    print("Received:", line)


await fetch_stream()
# Out:
# Received: Error: An error occurred (ResourceNotFoundException) when calling the ConverseStream operation: Access denied. This Model is marked by provider as Legacy and you have not been actively using the model in the last 30 days. Please upgrade to an active model on Amazon Bedrock
# Received: └ Bedrock region: us-east-1
# Received: └ Model id: us.anthropic.claude-sonnet-4-20250514-v1:0

# %% [markdown]
# ## Method 2 - Callback Handlers for streaming

# %% [markdown]
# Callback handlers are a powerful feature of the Strands Agents that allow you to intercept and process events as they happen during agent execution. This enables real-time monitoring, custom output formatting, and integration with external systems.

# %% [markdown]
# Callback handlers receive events in real-time as they occur during an agent's lifecycle:
#
# - Text generation from the model
# - Tool selection and execution
# - Reasoning process
# - Errors and completions
#
#
# Let's now create a custom callback handler function that formats the event inputs to highlight tool usage and model output. To do so, we will again use the agent with a calculator tool only
#
# <div style="text-align:left;">
#     <img src="images/architecture.png" width="65%" />
# </div>

# %%
def custom_callback_handler(**kwargs):
    # Process stream data
    if "data" in kwargs:
        print(f"MODEL OUTPUT: {kwargs['data']}")
    elif "current_tool_use" in kwargs and kwargs["current_tool_use"].get("name"):
        print(f"\nUSING TOOL: {kwargs['current_tool_use']['name']}")


# Create an agent with custom callback handler
agent = Agent(   
        model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
        tools=[calculator], 
        callback_handler=custom_callback_handler)

agent("Calculate 2+2")

# %% [markdown]
# ### Congratulations!
#
# In this notebook you learned how to stream your agents outputs using async iteractors and callback handlers.

# %% [markdown]
# # Adding custom tools to your Strands Agents
#
# ## Overview
# In this example we will guide you through the different ways to create custom tools using Strands Agents. We will build a personal assistant use case that connects with a local SQLite database to perform data tasks. As a bonus, we will also guide you through the usage of the reasoning capabilities on Claude Sonnet 4.5 using the `thinking` field of the `BedrockModel` class
#
# ## Agent Details
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Native tools used   |current_time, calculator                           |
# |Custom tools created|create_appointment, list_appointments              |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ## Architecture
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="85%" />
# </div>
#
# ## Key Features
# * **Single agent architecture**: this example creates a single agent that interacts with built-in and custom tools
# * **Built-in tools**: learn how to use Strands Agent's tools
# * **Custom tools**: lean how to create your own tools
# * **Bedrock Model as underlying LLM**: Used Anthropic Claude Sonnet 4.5 from Amazon Bedrock as the underlying LLM model

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * AWS account
# * Anthropic Claude Sonnet 4.5 enabled on Amazon Bedrock, [guide](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
# * IAM role with permissions to create Amazon Bedrock Knowledge Base, Amazon S3 bucket and Amazon DynamoDB
#
# Let's now install the requirement packages for our Strands Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: strands-agents-tools in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.94)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.13.3)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.94)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.28.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.33.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.5)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.3.4)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.12.1)
# Requirement already satisfied: propcache>=0.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (26.1.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.16.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.6.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.3)
# Requirement already satisfied: six<2,>=1.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: anyio>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.46.0)
# Requirement already satisfied: httpx>=0.27.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: starlette>=0.27 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.26)
# Requirement already satisfied: sse-starlette>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.3.4)
# Requirement already satisfied: httpx-sse>=0.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: packaging>=18.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (26.1)
# Requirement already satisfied: wcwidth in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.46.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: certifi>=2023.5.7 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2026.4.22)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.41.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8.3)
# Requirement already satisfied: httpcore==1.* in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.1)
# Requirement already satisfied: mdurl~=0.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (46.0.7)
# Requirement already satisfied: click>=7.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (8.3.3)
# Requirement already satisfied: cffi>=2.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: pycparser in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (3.0)

# %% [markdown]
# ### Importing dependency packages
#
# Now let's import the dependency packages

# %%
import json
import sqlite3
import uuid
from datetime import datetime

from strands import Agent, tool
from strands.models import BedrockModel

# %% [markdown]
# ## Defining custom tools
# Next let's define custom tools to interact with a local SQLite database:
# * **create_appointment**: create a new personal appointment with unique id, date, location, title and description
# * **list_appointment**: list all available appointments
# * **update_appointments**: update an appointment based on the appointment id

# %% [markdown]
# ### Defining tools in the same file of your agent
#
# There are multiple ways to define tools with the Strands Agents SDK. The first one is to add a `@tool` decorator to your function and provide the documentation to it. In this case, Strands Agents will use the function documentation, typing and arguments to provide the tools to your agent. In this case, you can even define the tool in the same file as your agent

# %%
@tool
def create_appointment(date: str, location: str, title: str, description: str) -> str:
    """
    Create a new personal appointment in the database.

    Args:
        date (str): Date and time of the appointment (format: YYYY-MM-DD HH:MM).
        location (str): Location of the appointment.
        title (str): Title of the appointment.
        description (str): Description of the appointment.

    Returns:
        str: The ID of the newly created appointment.

    Raises:
        ValueError: If the date format is invalid.
    """
    # Validate date format
    try:
        datetime.strptime(date, "%Y-%m-%d %H:%M")
    except ValueError:
        raise ValueError("Date must be in format 'YYYY-MM-DD HH:MM'")

    # Generate a unique ID
    appointment_id = str(uuid.uuid4())

    conn = sqlite3.connect("appointments.db")
    cursor = conn.cursor()

    # Create the appointments table if it doesn't exist
    cursor.execute(
        """
    CREATE TABLE IF NOT EXISTS appointments (
        id TEXT PRIMARY KEY,
        date TEXT,
        location TEXT,
        title TEXT,
        description TEXT
    )
    """
    )

    cursor.execute(
        "INSERT INTO appointments (id, date, location, title, description) VALUES (?, ?, ?, ?, ?)",
        (appointment_id, date, location, title, description),
    )

    conn.commit()
    conn.close()
    return f"Appointment with id {appointment_id} created"

# %% [markdown]
# ### Tool definition with Module-Based Approach
#
# You can also define your tools as a standalone file and import it to your agent. In this case you can still use the decorator approach or you could also define your function using a TOOL_SPEC dictionary. The formating is similar to the one used by the [Amazon Bedrock Converse API](https://docs.aws.amazon.com/bedrock/latest/userguide/tool-use-examples.html) for tool usage. In this case you are more flexible to define the required parameters as well as the return of success and error executions and TOOL_SPEC definitions will work in this case.

# %% [markdown]
# #### Decorator approach
#
# When defining your tool using a decorator in a standalone file, your process is very similar to the one in the same file as your agent, but you will need to import or agent tool later on.

# %%
# %%writefile list_appointments.py
import json
import sqlite3
import os
from strands import tool

@tool
def list_appointments() -> str:
    """
    List all available appointments from the database.
    
    Returns:
        str: the appointments available 
    """
    # Check if database exists
    if not os.path.exists('appointments.db'):
        return "No appointment available"
    
    conn = sqlite3.connect('appointments.db')
    conn.row_factory = sqlite3.Row  # This enables column access by name
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return "No appointment available"
        
        cursor.execute("SELECT * FROM appointments ORDER BY date")
        rows = cursor.fetchall()
        
        # Convert rows to dictionaries
        appointments = []
        for row in rows:
            appointment = {
                'id': row['id'],
                'date': row['date'],
                'location': row['location'],
                'title': row['title'],
                'description': row['description']
            }
            appointments.append(appointment)
        
        conn.close()
        return json.dumps(appointments)
    
    except sqlite3.Error:
        conn.close()
        return []
# Out:
# Writing list_appointments.py

# %% [markdown]
# #### TOOL_SPEC approach
#
# Alternativelly, you can use the TOOL_SPEC approach when defining your tool

# %%
# %%writefile update_appointment.py
import sqlite3
from datetime import datetime
import os
from strands.types.tools import ToolResult, ToolUse
from typing import Any

TOOL_SPEC = {
    "name": "update_appointment",
    "description": "Update an appointment based on the appointment ID.",
    "inputSchema": {
        "json": {
            "type": "object",
            "properties": {
                "appointment_id": {
                    "type": "string",
                    "description": "The appointment id."
                },
                "date": {
                    "type": "string",
                    "description": "Date and time of the appointment (format: YYYY-MM-DD HH:MM)."
                },
                "location": {
                    "type": "string",
                    "description": "Location of the appointment."
                },
                "title": {
                    "type": "string",
                    "description": "Title of the appointment."
                },
                "description": {
                    "type": "string",
                    "description": "Description of the appointment."
                }
            },
            "required": ["appointment_id"]
        }
    }
}
# Function name must match tool name
def update_appointment(tool: ToolUse, **kwargs: Any) -> ToolResult:
    tool_use_id = tool["toolUseId"]
    appointment_id = tool["input"]["appointment_id"]
    if "date" in tool["input"]:
        date = tool["input"]["date"]
    else:
        date = None
    if "location" in tool["input"]:
        location = tool["input"]["location"]
    else:
        location = None
    if "title" in tool["input"]:
        title = tool["input"]["title"]
    else:
        title = None
    if "description" in tool["input"]:
        description = tool["input"]["description"]
    else:
        description = None
        
    # Check if database exists
    if not os.path.exists('appointments.db'): 
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": f"Appointment {appointment_id} does not exist"}]
        } 
    
    # Check if appointment exists
    conn = sqlite3.connect('appointments.db')
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointments table does not exist"}]
            }
        
        cursor.execute("SELECT * FROM appointments WHERE id = ?", (appointment_id,))
        appointment = cursor.fetchone()
        
        if not appointment:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointment {appointment_id} does not exist"}]
            }
        
        # Validate date format if provided
        if date:
            try:
                datetime.strptime(date, '%Y-%m-%d %H:%M')
            except ValueError:
                conn.close()
                return {
                    "toolUseId": tool_use_id,
                    "status": "error",
                    "content": [{"text": "Date must be in format 'YYYY-MM-DD HH:MM'"}]
                }
        
        # Build update query
        update_fields = []
        params = []
        
        if date:
            update_fields.append("date = ?")
            params.append(date)
        
        if location:
            update_fields.append("location = ?")
            params.append(location)
        
        if title:
            update_fields.append("title = ?")
            params.append(title)
        
        if description:
            update_fields.append("description = ?")
            params.append(description)
        
        # If no fields to update
        if not update_fields:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "success",
                "content": [{"text": "No need to update your appointment, you are all set!"}]
            }
        
        # Complete the query
        query = f"UPDATE appointments SET {', '.join(update_fields)} WHERE id = ?"
        params.append(appointment_id)
        
        cursor.execute(query, params)
        conn.commit()
        conn.close()
        
        return {
            "toolUseId": tool_use_id,
            "status": "success",
            "content": [{"text": f"Appointment {appointment_id} updated with success"}]
        }
    
    except sqlite3.Error as e:
        conn.close()
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": str(e)}]
        }
# Out:
# Writing update_appointment.py

# %% [markdown]
# let's now import `list_appointments` and `update_appointment` as a tool

# %%
import list_appointments
import update_appointment

# %% [markdown]
# ## Creating Agent
#
# Now that we have created our custom tools, let's define our first agent. To do so, we need to create a system prompt that defines what the agent should and should not do. We will then define our agent's underlying LLM model and we will provide it with built-in and custom tools.
#
# #### Setting agent system prompt
# In the system prompt we will define the instructions for our agent

# %%
system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
Always provide the appointment id so that I can update it if required"""

# %% [markdown]
# #### Defining agent underlying LLM model
#
# Next let's define our agent underlying model. Strands Agents natively integrate with Amazon Bedrock models, and provides the ability to configure how the model is called. Below, you can see a simple initialization of a `BedrockModel` provider, with some of the optional configurations commented out. You can learn more about configuration options, and default values, at [Strands Agents Bedrock Model Provider documentation](https://strandsagents.com/0.1.x/user-guide/concepts/model-providers/amazon-bedrock/). For our example, we will use the `Anthropic Claude Sonnet 4.5` model from Bedrock.

# %%
model = BedrockModel(
    model_id="us.amazon.nova-2-lite-v1:0",
    # region_name="us-east-1",
    # boto_client_config=Config(
    #    read_timeout=900,
    #    connect_timeout=900,
    #    retries=dict(max_attempts=3, mode="adaptive"),
    # ),
    # temperature=0.9,
    # max_tokens=2048,
)

# %% [markdown]
# #### Import built-in tools
#
# The next step to build our agent is to import our Strands Agents built-in tools. Strands Agents provides a set of commonly used built-in tools in the optional package `strands-tools`. You have tools for RAG, memory, file operations, code interpretation and others available in this repo. For our example we will use the `current_time` tool to provide our agent with the information about the current time and the `calculator` tool to do some math

# %%
from strands_tools import calculator, current_time

# %% [markdown]
# #### Defining Agent
#
# Now that we have all the required information available, let's define our agent

# %%
agent = Agent(
    model=model,
    system_prompt=system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

# %% [markdown]
# ## Invoking agent
#
# Let's now invoke our restaurant agent with a greeting and analyse its results

# %%
results = agent("How much is 2+2?")
# Out:
# Tool #1: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 2+2                 │                                                                            │
# │  │ Result    │ 4                   │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The result of 2+2 is **4**.

# %% [markdown]
# #### Analysing the agent's results
#
# Nice! We've invoked our agent for the first time! Let's now explore the results object. First thing we can see is the messages being exchanged by the agent in the agent's object

# %%
agent.messages
# Out:
# [{'role': 'user', 'content': [{'text': 'How much is 2+2?'}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ',
#      'name': 'calculator',
#      'input': {'expression': '2+2'}}}],
#   'metadata': {'usage': {'inputTokens': 2524,
#     'outputTokens': 27,
#     'totalTokens': 2551},
#    'metrics': {'latencyMs': 848, 'timeToFirstByteMs': 1203}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'status': 'success',
#      'content': [{'text': 'Result: 4'}],
#      'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ'}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'The result of 2+2 is **4**.'}],
#   'metadata': {'usage': {'inputTokens': 2580,
#     'outputTokens': 14,
#     'totalTokens': 2594},
#    'metrics': {'latencyMs': 523, 'timeToFirstByteMs': 645}}}]

# %% [markdown]
# Next we can take a look at the usage of our agent for the last query by analysing the result `metrics`

# %%
results.metrics
# Out:
# EventLoopMetrics(cycle_count=2, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ', 'name': 'calculator', 'input': {'expression': '2+2'}}, call_count=1, success_count=1, error_count=0, total_time=0.06569147109985352)}, cycle_durations=[1.3878538608551025, 0.6510133743286133], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='ac15c88c-bba4-439a-a293-1e922f7af8dd', usage={'inputTokens': 2524, 'outputTokens': 27, 'totalTokens': 2551}), EventLoopCycleMetric(event_loop_cycle_id='673534e1-8171-4570-9a9e-98b5121a5488', usage={'inputTokens': 2580, 'outputTokens': 14, 'totalTokens': 2594})], usage={'inputTokens': 5104, 'outputTokens': 41, 'totalTokens': 5145})], traces=[<strands.telemetry.metrics.Trace object at 0xffff541de2f0>, <strands.telemetry.metrics.Trace object at 0xffff55442770>], accumulated_usage={'inputTokens': 5104, 'outputTokens': 41, 'totalTokens': 5145}, accumulated_metrics={'latencyMs': 1371})

# %% [markdown]
# #### Invoking agent with follow up question
# Ok, let's now make an appointment for tomorrow

# %%
results = agent(
    "Book 'Agent fun' for tomorrow 3pm in NYC. This meeting will discuss all the fun things that an agent can do"
)
# Out:
# Tool #2: current_time
#
# Tool #3: create_appointment
# Your appointment titled **"Agent fun"** has been successfully scheduled for **tomorrow at 3 PM in NYC**.
#
# The appointment ID is **24e25e1e-2734-4deb-8ffc-a8531266bb65**.
# You can use this ID if you need to update or cancel the appointment later.
#
# The meeting will discuss all the fun things that an agent can do.

# %% [markdown]
# #### Updating appointment
#
# Let's now update this appointment

# %%
results = agent("Oh no! My bad, 'Agent fun' is actually happening in DC")
# Out:
# Tool #4: update_appointment
# Your appointment titled **"Agent fun"** has been successfully updated.
#
# The location has been changed from **NYC** to **DC**.
#
# The appointment ID remains **24e25e1e-2734-4deb-8ffc-a8531266bb65**.
# The meeting is still scheduled for **tomorrow at 3 PM** and will discuss all the fun things that an agent can do.

# %% [markdown]
# #### Analysing the agent's results
# Let's look at the agent messages and result metrics again

# %%
agent.messages
# Out:
# [{'role': 'user', 'content': [{'text': 'How much is 2+2?'}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ',
#      'name': 'calculator',
#      'input': {'expression': '2+2'}}}],
#   'metadata': {'usage': {'inputTokens': 2524,
#     'outputTokens': 27,
#     'totalTokens': 2551},
#    'metrics': {'latencyMs': 848, 'timeToFirstByteMs': 1203}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'status': 'success',
#      'content': [{'text': 'Result: 4'}],
#      'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ'}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'The result of 2+2 is **4**.'}],
#   'metadata': {'usage': {'inputTokens': 2580,
#     'outputTokens': 14,
#     'totalTokens': 2594},
#    'metrics': {'latencyMs': 523, 'timeToFirstByteMs': 645}}},
#  {'role': 'user',
#   'content': [{'text': "Book 'Agent fun' for tomorrow 3pm in NYC. This meeting will discuss all the fun things that an agent can do"}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_wfqB9qWHZmzAgRxyitcmjY',
#      'name': 'current_time',
#      'input': {}}}],
#   'metadata': {'usage': {'inputTokens': 2622,
#     'outputTokens': 14,
#     'totalTokens': 2636},
#    'metrics': {'latencyMs': 466, 'timeToFirstByteMs': 565}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_wfqB9qWHZmzAgRxyitcmjY',
#      'status': 'success',
#      'content': [{'text': '2026-04-25T14:46:01.945567+00:00'}]}}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_WU7btSRHvhBJmmfdY5pcBz',
#      'name': 'create_appointment',
#      'input': {'date': '2026-04-26 15:00',
#       'description': 'This meeting will discuss all the fun things that an agent can do',
#       'location': 'NYC',
#       'title': 'Agent fun'}}}],
#   'metadata': {'usage': {'inputTokens': 2680,
#     'outputTokens': 78,
#     'totalTokens': 2758},
#    'metrics': {'latencyMs': 763, 'timeToFirstByteMs': 649}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_WU7btSRHvhBJmmfdY5pcBz',
#      'status': 'success',
#      'content': [{'text': 'Appointment with id 24e25e1e-2734-4deb-8ffc-a8531266bb65 created'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'Your appointment titled **"Agent fun"** has been successfully scheduled for **tomorrow at 3 PM in NYC**. \n\nThe appointment ID is **24e25e1e-2734-4deb-8ffc-a8531266bb65**. \nYou can use this ID if you need to update or cancel the appointment later. \n\nThe meeting will discuss all the fun things that an agent can do.'}],
#   'metadata': {'usage': {'inputTokens': 2810,
#     'outputTokens': 85,
#     'totalTokens': 2895},
#    'metrics': {'latencyMs': 730, 'timeToFirstByteMs': 717}}},
#  {'role': 'user',
#   'content': [{'text': "Oh no! My bad, 'Agent fun' is actually happening in DC"}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_5N712toBsS77tsT0OxL8r9',
#      'name': 'update_appointment',
#      'input': {'appointment_id': '24e25e1e-2734-4deb-8ffc-a8531266bb65',
#       'location': 'DC'}}}],
#   'metadata': {'usage': {'inputTokens': 2912,
#     'outputTokens': 59,
#     'totalTokens': 2971},
#    'metrics': {'latencyMs': 738, 'timeToFirstByteMs': 593}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_5N712toBsS77tsT0OxL8r9',
#      'status': 'success',
#      'content': [{'text': 'Appointment 24e25e1e-2734-4deb-8ffc-a8531266bb65 updated with success'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'Your appointment titled **"Agent fun"** has been successfully updated. \n\nThe location has been changed from **NYC** to **DC**. \n\nThe appointment ID remains **24e25e1e-2734-4deb-8ffc-a8531266bb65**. \nThe meeting is still scheduled for **tomorrow at 3 PM** and will discuss all the fun things that an agent can do.'}],
#   'metadata': {'usage': {'inputTokens': 3024,
#     'outputTokens': 85,
#     'totalTokens': 3109},
#    'metrics': {'latencyMs': 740, 'timeToFirstByteMs': 603}}}]

# %%
results.metrics
# Out:
# EventLoopMetrics(cycle_count=7, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_8CzKy8m4OfHXvfYbuh7QsQ', 'name': 'calculator', 'input': {'expression': '2+2'}}, call_count=1, success_count=1, error_count=0, total_time=0.06569147109985352), 'current_time': ToolMetrics(tool={'toolUseId': 'tooluse_wfqB9qWHZmzAgRxyitcmjY', 'name': 'current_time', 'input': {}}, call_count=1, success_count=1, error_count=0, total_time=0.002070903778076172), 'create_appointment': ToolMetrics(tool={'toolUseId': 'tooluse_WU7btSRHvhBJmmfdY5pcBz', 'name': 'create_appointment', 'input': {'date': '2026-04-26 15:00', 'description': 'This meeting will discuss all the fun things that an agent can do', 'location': 'NYC', 'title': 'Agent fun'}}, call_count=1, success_count=1, error_count=0, total_time=0.04238533973693848), 'update_appointment': ToolMetrics(tool={'toolUseId': 'tooluse_5N712toBsS77tsT0OxL8r9', 'name': 'update_appointment', 'input': {'appointment_id': '24e25e1e-2734-4deb-8ffc-a8531266bb65', 'location': 'DC'}}, call_count=1, success_count=1, error_count=0, total_time=0.03699445724487305)}, cycle_durations=[1.3878538608551025, 0.6510133743286133, 0.600341796875, 1.0312445163726807, 0.8584475517272949, 0.9057891368865967, 0.8678514957427979], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='ac15c88c-bba4-439a-a293-1e922f7af8dd', usage={'inputTokens': 2524, 'outputTokens': 27, 'totalTokens': 2551}), EventLoopCycleMetric(event_loop_cycle_id='673534e1-8171-4570-9a9e-98b5121a5488', usage={'inputTokens': 2580, 'outputTokens': 14, 'totalTokens': 2594})], usage={'inputTokens': 5104, 'outputTokens': 41, 'totalTokens': 5145}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='a39668d6-bc35-48ff-88e2-917d9da84e6a', usage={'inputTokens': 2622, 'outputTokens': 14, 'totalTokens': 2636}), EventLoopCycleMetric(event_loop_cycle_id='1b5cbc5b-6335-4482-b33a-31bdbbc54efe', usage={'inputTokens': 2680, 'outputTokens': 78, 'totalTokens': 2758}), EventLoopCycleMetric(event_loop_cycle_id='7ab3ad65-e786-4a13-a5ab-043a5889a372', usage={'inputTokens': 2810, 'outputTokens': 85, 'totalTokens': 2895})], usage={'inputTokens': 8112, 'outputTokens': 177, 'totalTokens': 8289}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='ae14464e-537e-4699-81c2-4da80f043a84', usage={'inputTokens': 2912, 'outputTokens': 59, 'totalTokens': 2971}), EventLoopCycleMetric(event_loop_cycle_id='12369fc9-8fd5-4ca0-8758-5e75eee491e1', usage={'inputTokens': 3024, 'outputTokens': 85, 'totalTokens': 3109})], usage={'inputTokens': 5936, 'outputTokens': 144, 'totalTokens': 6080})], traces=[<strands.telemetry.metrics.Trace object at 0xffff541de2f0>, <strands.telemetry.metrics.Trace object at 0xffff55442770>, <strands.telemetry.metrics.Trace object at 0xffff541dfdc0>, <strands.telemetry.metrics.Trace object at 0xffff545842b0>, <strands.telemetry.metrics.Trace object at 0xffff5657c070>, <strands.telemetry.metrics.Trace object at 0xffff541dff10>, <strands.telemetry.metrics.Trace object at 0xffff565674f0>], accumulated_usage={'inputTokens': 19152, 'outputTokens': 362, 'totalTokens': 19514}, accumulated_metrics={'latencyMs': 4808})

# %% [markdown]
# #### Checking tool usage from messages
#
# Let's deep-dive into the tool usage in the messages dictionary. Later on we will show case how to observe and evaluate your agent's behavior, but this is the first step in this direction

# %%
for m in agent.messages:
    for content in m["content"]:
        if "toolUse" in content:
            print("Tool Use:")
            tool_use = content["toolUse"]
            print("\tToolUseId: ", tool_use["toolUseId"])
            print("\tname: ", tool_use["name"])
            print("\tinput: ", tool_use["input"])
        if "toolResult" in content:
            print("Tool Result:")
            tool_result = m["content"][0]["toolResult"]
            print("\tToolUseId: ", tool_result["toolUseId"])
            print("\tStatus: ", tool_result["status"])
            print("\tContent: ", tool_result["content"])
            print("=======================")
# Out:
# Tool Use:
# 	ToolUseId:  tooluse_8CzKy8m4OfHXvfYbuh7QsQ
# 	name:  calculator
# 	input:  {'expression': '2+2'}
# Tool Result:
# 	ToolUseId:  tooluse_8CzKy8m4OfHXvfYbuh7QsQ
# 	Status:  success
# 	Content:  [{'text': 'Result: 4'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_wfqB9qWHZmzAgRxyitcmjY
# 	name:  current_time
# 	input:  {}
# Tool Result:
# 	ToolUseId:  tooluse_wfqB9qWHZmzAgRxyitcmjY
# 	Status:  success
# 	Content:  [{'text': '2026-04-25T14:46:01.945567+00:00'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_WU7btSRHvhBJmmfdY5pcBz
# 	name:  create_appointment
# 	input:  {'date': '2026-04-26 15:00', 'description': 'This meeting will discuss all the fun things that an agent can do', 'location': 'NYC', 'title': 'Agent fun'}
# Tool Result:
# 	ToolUseId:  tooluse_WU7btSRHvhBJmmfdY5pcBz
# 	Status:  success
# 	Content:  [{'text': 'Appointment with id 24e25e1e-2734-4deb-8ffc-a8531266bb65 created'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_5N712toBsS77tsT0OxL8r9
# 	name:  update_appointment
# 	input:  {'appointment_id': '24e25e1e-2734-4deb-8ffc-a8531266bb65', 'location': 'DC'}
# Tool Result:
# 	ToolUseId:  tooluse_5N712toBsS77tsT0OxL8r9
# 	Status:  success
# 	Content:  [{'text': 'Appointment 24e25e1e-2734-4deb-8ffc-a8531266bb65 updated with success'}]
# =======================

# %% [markdown]
# ### Validating that the action was performed correctly
# Let's now check our database to confirm that the operations where done correctly. The `Agent` class has the ability for directly calling tools the agent was initialized with by calling `agent.tool.<tool_name>(<tool_params>)`. Direct tool calls are great for giving the agent information from a tool without needing the agent to invoke that tool itself. We can use this direct tool invocation to list the current appointments:

# %%
list_appointments_result = agent.tool.list_appointments()
print(json.dumps(list_appointments_result, indent=2))
# Out:
# {
#   "toolUseId": "tooluse_list_appointments_937809499",
#   "status": "success",
#   "content": [
#     {
#       "text": "[{\"id\": \"24e25e1e-2734-4deb-8ffc-a8531266bb65\", \"date\": \"2026-04-26 15:00\", \"location\": \"DC\", \"title\": \"Agent fun\", \"description\": \"This meeting will discuss all the fun things that an agent can do\"}]"
#     }
#   ]
# }

# %% [markdown]
# We can see that the result of executing the tool is in the ToolResult format, including a `toolUseId`, an execution `status`, and the `content` of the response. We can better visualize the tool's result like this:

# %%
list_appointments_result_text_content = list_appointments_result["content"][0]["text"]
print(json.dumps(json.loads(list_appointments_result_text_content), indent=2))
# Out:
# [
#   {
#     "id": "24e25e1e-2734-4deb-8ffc-a8531266bb65",
#     "date": "2026-04-26 15:00",
#     "location": "DC",
#     "title": "Agent fun",
#     "description": "This meeting will discuss all the fun things that an agent can do"
#   }
# ]

# %% [markdown]
# Finally, when executing tools using direct tool invocation, the agent records these executions in its messages history. By default this is enabled, but can be disabled with the `record_direct_tool_call` boolean flag attribute on the `Agent` class.

# %%
current_time_result = agent.tool.current_time()
print("Current Time direct tool call result:")
print(current_time_result)
current_time_direct_tool_messages = agent.messages[-4:]
print("Current Time direct tool call messages:")
print(current_time_direct_tool_messages)

agent.record_direct_tool_call = False # Set the record_direct_tool_call to False
agent.tool.list_appointments()
after_disable_record_messages = agent.messages[-4:]
print("After disabling record direct tool call messages, history should not have changed:")
print(current_time_direct_tool_messages == after_disable_record_messages)
# Out:
# Current Time direct tool call result:
# {'toolUseId': 'tooluse_current_time_932768756', 'status': 'success', 'content': [{'text': '2026-04-25T14:48:05.769850+00:00'}]}
# Current Time direct tool call messages:
# [{'role': 'user', 'content': [{'text': 'agent.tool.current_time direct tool call.\nInput parameters: {}\n'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_current_time_932768756', 'name': 'current_time', 'input': {}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_current_time_932768756', 'status': 'success', 'content': [{'text': '2026-04-25T14:48:05.769850+00:00'}]}}]}, {'role': 'assistant', 'content': [{'text': 'agent.tool.current_time was called.'}]}]
# After disabling record direct tool call messages, history should not have changed:
# True

# %% [markdown]
# ## Extension: Extended Thinking
#
# Extended thinking enables supported Claude-family models the ability to leverage enhanced reasoning capabilities for complex tasks, providing transparent step-by-step thought processes before delivering final answers. To enable thinking, you can include the configuration below when configuring your Bedrock ModelProvider. You can learn more at [AWS's documentation on Extended Thinking](https://docs.aws.amazon.com/bedrock/latest/userguide/claude-messages-extended-thinking.html).

# %%
thinking_model = BedrockModel(
    model_id="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    additional_request_fields={
        "thinking": {
            "type": "enabled",
            "budget_tokens": 2048,
        }
    },
)

# %% [markdown]
# After defining the `thinking_model`, you can create and invoke a new `thinking_agent`:

# %%
thinking_system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
You think through your problem, step by step, to come up with an answer.
Always provide the appointment id so that I can update it if required"""

thinking_agent = Agent(
    model=thinking_model,
    system_prompt=thinking_system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

thinking_result = thinking_agent("I want to add a new appointment for tomorrow at 2pm")
# Out:
# The user wants to create a new appointment for tomorrow at 2pm. To do this, I need to:
# 1. First, get the current time to determine what "tomorrow" is
# 2. Then create the appointment with the date set to tomorrow at 2pm
#
# However, I notice that the create_appointment function requires:
# - date (format: YYYY-MM-DD HH:MM)
# - title
# - location
# - description
#
# The user has only provided the date/time (tomorrow at 2pm) but hasn't provided:
# - title
# - location
# - description
#
# I should ask the user for these required details before creating the appointment.I'd be happy to help you create an appointment for tomorrow at 2pm! However, I need a few more details to complete the appointment:
#
# 1. **Title** - What would you like to call this appointment?
# 2. **Location** - Where will this appointment take place?
# 3. **Description** - Can you provide a brief description of the appointment?
#
# Please provide these details and I'll create the appointment for you.

# %% [markdown]
# We can better analyze the extended thinking capabilities by printing out the agent's messages. Extended thinking is represented as `reasoningContent` blocks in the response from the agent.

# %%
thinking_agent.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': 'I want to add a new appointment for tomorrow at 2pm'}]},
#  {'role': 'assistant',
#   'content': [{'reasoningContent': {'reasoningText': {'text': 'The user wants to create a new appointment for tomorrow at 2pm. To do this, I need to:\n1. First, get the current time to determine what "tomorrow" is\n2. Then create the appointment with the date set to tomorrow at 2pm\n\nHowever, I notice that the create_appointment function requires:\n- date (format: YYYY-MM-DD HH:MM)\n- title\n- location\n- description\n\nThe user has only provided the date/time (tomorrow at 2pm) but hasn\'t provided:\n- title\n- location\n- description\n\nI should ask the user for these required details before creating the appointment.',
#       'signature': '...'}}},
#    {'text': "I'd be happy to help you create an appointment for tomorrow at 2pm! However, I need a few more details to complete the appointment:\n\n1. **Title** - What would you like to call this appointment?\n2. **Location** - Where will this appointment take place?\n3. **Description** - Can you provide a brief description of the appointment?\n\nPlease provide these details and I'll create the appointment for you."}],
#   'metadata': {'usage': {'inputTokens': 2552,
#     'outputTokens': 240,
#     'totalTokens': 2792},
#    'metrics': {'latencyMs': 4082, 'timeToFirstByteMs': 1372}}}]

# %% [markdown]
# ## Great work !
# See you in the next module. :)

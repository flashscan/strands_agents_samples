# %% [markdown]
# # Persisting memory across Strands Agents sessions
#
# In this example you will learn how to persist memory across different sessions in your Strands Agents.
#
# We will use the use case of an agent that does web search using a `duckduckgo` search API.
#
# In this notebook, we will:
# - Explore the capabilities of a memory-powered Strands agent.
# - Learn how to store, retrieve, and list memories.
# - Understand how to perform web searches via the agent.
# - Interact with the agent in an interactive loop.
#
#
# ### Usage Examples
#
# Storing memories:
# ```
# Remember that I prefer tea over coffee
# ```
#
# Retrieving memories:
# ```
# What do I prefer to drink?
# ```
#
# Listing all memories:
# ```
# Show me everything you remember about me
# ```
#
# ### Tips for Memory Usage
#
# - Be explicit when asking the agent to remember information
# - Use specific queries to retrieve relevant memories
# - Memory persistence enables more natural and contextual conversations

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * AWS account and AWS credentials configured in the environment
# * Anthropic Claude Sonnet 4.5 enabled on Amazon Bedrock
# * IAM role with permissions to create Amazon Bedrock Knowledge Base, Amazon S3 bucket and Amazon DynamoDB
#
# Let's now install the requirement packages for our Strands Agent

# %%
# Install the required packages
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (1.37.0)
# Requirement already satisfied: strands-agents-tools in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: mem0ai in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: boto3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.42.96)
# Requirement already satisfied: opensearch-py in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: ddgs in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (9.14.1)
# Requirement already satisfied: python-dotenv in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (2.13.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.41.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.96)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (1.27.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.12.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.28.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.5)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.33.1)
# Requirement already satisfied: pytz>=2024.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (2026.1.post1)
# Requirement already satisfied: protobuf<7.0.0,>=5.29.6 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (6.33.6)
# Requirement already satisfied: openai>=1.90.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (2.32.0)
# Requirement already satisfied: sqlalchemy>=2.0.31 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (2.0.49)
# Requirement already satisfied: posthog>=4.5.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (7.13.1)
# Requirement already satisfied: qdrant-client>=1.12.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mem0ai->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from boto3->-r requirements.txt (line 4)) (0.16.1)
# Requirement already satisfied: python-dateutil in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-py->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: opensearch-protobufs==0.19.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-py->-r requirements.txt (line 5)) (0.19.0)
# Requirement already satisfied: urllib3!=2.2.0,!=2.2.1,<3,>=1.26.19 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-py->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: Events in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-py->-r requirements.txt (line 5)) (0.5)
# Requirement already satisfied: certifi>=2024.07.04 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-py->-r requirements.txt (line 5)) (2026.4.22)
# Requirement already satisfied: grpcio>=1.68.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opensearch-protobufs==0.19.0->opensearch-py->-r requirements.txt (line 5)) (1.80.0)
# Requirement already satisfied: lxml>=4.9.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from ddgs->-r requirements.txt (line 6)) (6.1.0)
# Requirement already satisfied: click>=8.1.8 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from ddgs->-r requirements.txt (line 6)) (8.3.3)
# Requirement already satisfied: primp>=1.2.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from ddgs->-r requirements.txt (line 6)) (1.2.3)
# Requirement already satisfied: attrs>=17.3.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (26.1.0)
# Requirement already satisfied: aiosignal>=1.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.23.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: propcache>=0.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: six<2,>=1.15 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.3)
# Requirement already satisfied: uvicorn>=0.31.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.46.0)
# Requirement already satisfied: httpx>=0.27.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: sse-starlette>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.3.4)
# Requirement already satisfied: httpx-sse>=0.4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: python-multipart>=0.0.9 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.26)
# Requirement already satisfied: starlette>=0.27 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.0)
# Requirement already satisfied: anyio>=4.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from openai>=1.90.0->mem0ai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: sniffio in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from openai>=1.90.0->mem0ai->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from openai>=1.90.0->mem0ai->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: tqdm>4 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from openai>=1.90.0->mem0ai->-r requirements.txt (line 3)) (4.67.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (8.7.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: packaging>=18.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (26.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.62b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.62b0)
# Requirement already satisfied: backoff>=1.10.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from posthog>=4.5.0->mem0ai->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: wcwidth in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.46.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: numpy<2.3.0,>=1.21 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from qdrant-client>=1.12.0->mem0ai->-r requirements.txt (line 3)) (2.2.6)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from qdrant-client>=1.12.0->mem0ai->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.41.0)
# Requirement already satisfied: greenlet>=1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from sqlalchemy>=2.0.31->mem0ai->-r requirements.txt (line 3)) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8.3)
# Requirement already satisfied: httpcore==1.* in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: zipp>=3.20 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents->-r requirements.txt (line 1)) (3.23.1)
# Requirement already satisfied: mdurl~=0.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (46.0.7)
# Requirement already satisfied: cffi>=2.0.0 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: hpack<5,>=4.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from h2<5,>=3->httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from h2<5,>=3->httpx>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: pycparser in /mnt/strands_agents_samples/.venv/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt<3.0.0,>=2.10.1->strands-agents-tools->-r requirements.txt (line 2)) (3.0)

# %%
# Import Required Libraries
import os

# --- mem0 LLM (for extracting memory) ---
os.environ["MEM0_LLM_PROVIDER"] = "aws_bedrock"
os.environ["MEM0_LLM_MODEL"] = "us.anthropic.claude-sonnet-4-5-20250929-v1:0"

# --- mem0 Embedding model ---
#os.environ["MEM0_EMBEDDING_PROVIDER"] = "aws_bedrock"
#os.environ["MEM0_EMBEDDING_MODEL"] = "amazon.titan-embed-text-v1"

from strands import Agent, tool
from strands.models import bedrock
from strands_tools import mem0_memory
import time

from ddgs import DDGS
from ddgs.exceptions import DDGSException, RatelimitException


os.environ["AWS_REGION"] = os.environ.get("AWS_REGION", "us-east-1")

bedrock.DEFAULT_BEDROCK_MODEL_ID = "us.anthropic.claude-sonnet-4-5-20250929-v1:0" #Optional: Set a default model for Bedrock

# %% [markdown]
# ## Mem0 Configuration
#
# ### Memory Backend Options
#
# The Mem0 Memory Tool supports three different backend configurations:
#
# 1. **[OpenSearch](https://aws.amazon.com/opensearch-service/features/serverless/)** (Recommended for AWS environments):
#    - Requires AWS credentials and OpenSearch configuration
#    - Set `OPENSEARCH_HOST` and optionally `AWS_REGION` (defaults to us-west-2)
#
# 2. **[FAISS]((https://faiss.ai/index.html))** (Default for local development):
#    - Uses FAISS as the local vector store backend
#    - Requires faiss-cpu package for local vector storage
#    - No additional configuration needed
#
# 3. **Mem0 Platform**:
#    - Uses the [Mem0 Platform API](https://docs.mem0.ai/platform/quickstart) for memory management
#    - Requires a Mem0 API key : `MEM0_API_KEY` in the environment variables
#
#
# ### Environment Configuration
#
# | Environment Variable | Description | Default | Required For |
# |---------------------|-------------|----------|--------------|
# | OPENSEARCH_HOST | OpenSearch Serverless Host URL | None | OpenSearch |
# | AWS_REGION | AWS Region for OpenSearch | us-west-2 | OpenSearch |
# | MEM0_API_KEY | Mem0 Platform API key | None | Mem0 Platform |
# | DEV | Enable development mode | false | All modes |
#
#
# For the scope of this lab, we can use 2 options as a backend for memory management:
# ### Option 1. [Opensearch Serverless](https://aws.amazon.com/opensearch-service/features/serverless/)
#
# This will be our setup architecture for AOSS:
#
# <div style="text-align:left">
#     <img src="images/arch_AOSS.png" width="65%" />
# </div>

# %%
# You can manually define your Opensearch Host 
#os.environ["OPENSEARCH_HOST"] = "<your-opensearch-host>.<region>.aoss.amazonaws.com"

# %%
# OR - Run the script to Create Opensearch Serverless resource in your AWS Account
# !bash prereqs/deploy_OSS.sh
# Out:
# deploying opensearch Serverless ...
# Configuration loaded: {'opensearch_collection_name': 'memory-store', 'opensearch_description': 'Memory vector store'}
# Creating OpenSearch Serverless collection: memory-store
# Collection memory-store already exists, using existing collection.
# Environment variables saved to /mnt/strands_agents_samples/python/01-learn/06-memory/.env
# OpenSearch Serverless collection setup completed!
#
# OPENSEARCH_HOST: rz3mgj4qysnv92mzofzl.us-east-1.aoss.amazonaws.com
# OPENSEARCH_COLLECTION_ID: rz3mgj4qysnv92mzofzl
#
# Environment variables saved to /mnt/strands_agents_samples/python/01-learn/06-memory/.env

# %%
wait_time = 120
print(f"Waiting {wait_time} seconds for OpenSearch Serverless collection to be fully operational...")
time.sleep(wait_time)
# Out:
# Waiting 120 seconds for OpenSearch Serverless collection to be fully operational...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 wait_time = 120
#       2 print(f"Waiting {wait_time} seconds for OpenSearch Serverless collection to be fully operational...")
# ----> 3 time.sleep(wait_time)
#
# KeyboardInterrupt:

# %%
# Option 1: Opensearch Serverless
from dotenv import load_dotenv
load_dotenv() # take Opensearch environment variables
# Out:
# True

# %% [markdown]
# ### Option 2 [Mem0 Platform](https://docs.mem0.ai/platform):
#
# #### [NOTE]: This is not Needed if you have already deployed the Opensearch Serverless option.
#
# As an alternative, you can create Mem0 API keys by following the steps [here](https://docs.mem0.ai/platform/quickstart#2-api-key-setup) and add it as an environment variable **MEM0_API_KEY**.
# This would be the architecture of the setup for Mem0 Platform:
#
# <div style="text-align:left">
#     <img src="images/arch_mem0.png" width="65%" />
# </div>
#
#
# To enable the agent's functionality, we need to configure environment variables for AWS credentials and OpenSearch / Mem0 Platform. These variables are used for memory storage and retrieval.

# %%
# Option 2: Mem0 API key

#os.environ["MEM0_API_KEY"] = "<your-mem0-api-key>"

# %% [markdown]
# ## Define System Prompt
#
# The `SYSTEM_PROMPT` variable defines the behavior and capabilities of the memory agent. This prompt guides the agent to provide personalized responses based on stored memories and perform web searches when necessary.

# %%
# Define a focused system prompt for memory operations
SYSTEM_PROMPT = """You are a helpful personal assistant for a user. Your task is to assist the user by providing personalized responses based on their history. 

Capabilities:
- You can store information using the mem0_memory tool,  mem0_memory(action="store", query="...", user_id=USER_ID)
- You can retrieve relevant memories using the mem0_memory tool, mem0_memory(action="retrieve", query="...", filters={"user_id": "..."})
- You can use duckduckgo_search to find information on the web.

Key Rules:
- Be conversational and natural in your responses.
- Always retrieve memories before responding to the user and use them to inform your response.
- Store any new user information and user preferences in mem0_memory.
- Only share relevant information.
- Politely indicate when you don't have the information.
"""

# %% [markdown]
# ## Define Web Search Tool
#
# The `websearch` tool using [Duckduckgo Search API](https://github.com/deedy5/duckduckgo_search) function allows the agent to perform web searches. This function handles exceptions and returns search results or appropriate error messages.

# %%
@tool
def websearch(
    keywords: str,
    region: str = "us-en",
    max_results: int | None = None,
) -> str:
    """Search the web to get updated information.
    Args:
        keywords (str): The search query keywords.
        region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc..
        max_results (int | None): The maximum number of results to return.
    Returns:
        List of dictionaries with search results.
    """
    try:
        results = DDGS().text(keywords, region=region, max_results=max_results)
        return results if results else "No results found."
    except RatelimitException:
        return "RatelimitException: Please try again after a short delay."
    except DDGSException as d:
        return f"DuckDuckGoSearchException: {d}"
    except Exception as e:
        return f"Exception: {e}"

# %% [markdown]
# ## Create Memory Agent
#
# We will now initialize the memory-focused agent using the defined tools and system prompt. The Strands agent is capable of:
# 1. Storing and retrieving memories based on context. It uses memory to create more personalized and contextual AI interactions.
# 2. Performing web searches using DuckDuckGo to give updated information.

# %%
# Create an agent with memory, websearch tool
USER_ID = "new_user" # Replace with actual user ID


from strands.models import BedrockModel
model = BedrockModel(
    model_id="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    region_name="us-east-1",
    # boto_client_config=Config(
    #    read_timeout=900,
    #    connect_timeout=900,
    #    retries=dict(max_attempts=3, mode="adaptive"),
    # ),
    # temperature=0.9,
    # max_tokens=2048,
)

memory_agent = Agent(
    system_prompt=SYSTEM_PROMPT,
    model=model,  # Optional: Specify the model ID
    tools=[mem0_memory, websearch],
)

# %% [markdown]
# ## Demonstrate Memory Operations
#
# The following examples demonstrate how to store, retrieve, and list memories using the memory agent.
#
# - **store**: Save important information for later retrieval
#   - Store user preferences
#   - Remember important facts
#   - Maintain conversation context
#
# - **retrieve**: Access relevant memories based on queries
#   - Find previously stored information
#   - Provide personalized responses based on user history
#
# - **list**: View all stored memories
#   - See what information has been retained
#   - Audit stored memories

# %%
# Store initial memories to demonstrate retrieval
memory_agent.tool.mem0_memory(
    action="store", content=f"The user's name is {USER_ID}.", user_id=USER_ID
)
memory_agent.tool.mem0_memory(
    action="store", 
    content="I like to drink tea more than coffee.", 
    filters={'user_id': USER_ID}
)
# Out:
# Model us.anthropic.claude-sonnet-4-5-20250929-v1:0 may not be available in region us-east-1
# ╭─────────────────────────────────────────── Memory for user new_user ────────────────────────────────────────────╮
# │ The user's name is new_user.                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Model us.anthropic.claude-sonnet-4-5-20250929-v1:0 may not be available in region us-east-1
# ╭──────────────────────────────────────────────────── agent  ─────────────────────────────────────────────────────╮
# │ I like to drink tea more than coffee.                                                                           │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────── ❌ Memory Operation Error ───────────────────────────────────────────╮
# │ Either user_id or agent_id must be provided                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'toolUseId': 'tooluse_mem0_memory_546908909',
#  'status': 'error',
#  'content': [{'text': 'Error: Either user_id or agent_id must be provided'}]}

# %%
# Retrieve memories
retrieved_memories = memory_agent.tool.mem0_memory(
    action="retrieve", query="What is the user's name?", filters={'user_id': "new_user"}
)
print("Retrieved Memories:", retrieved_memories)
# Out:
# Model us.anthropic.claude-sonnet-4-5-20250929-v1:0 may not be available in region us-east-1
# ╭─────────────────────────────────────────── ❌ Memory Operation Error ───────────────────────────────────────────╮
# │ Top-level entity parameters frozenset({'user_id', 'agent_id'}) are not supported in search(). Use               │
# │ filters={'user_id': '...'} instead.                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Retrieved Memories: {'toolUseId': 'tooluse_mem0_memory_642785649', 'status': 'error', 'content': [{'text': "Error: Top-level entity parameters frozenset({'user_id', 'agent_id'}) are not supported in search(). Use filters={'user_id': '...'} instead."}]}

# %%
# Retrieve memories about preferences
memory_agent.tool.mem0_memory(
    action="retrieve",
    query="What are the my drink preferences?",
    user_id=USER_ID
)
# Out:
# Model us.anthropic.claude-sonnet-4-5-20250929-v1:0 may not be available in region us-east-1
# ╭─────────────────────────────────────────── ❌ Memory Operation Error ───────────────────────────────────────────╮
# │ Top-level entity parameters frozenset({'user_id', 'agent_id'}) are not supported in search(). Use               │
# │ filters={'user_id': '...'} instead.                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'toolUseId': 'tooluse_mem0_memory_813808844',
#  'status': 'error',
#  'content': [{'text': "Error: Top-level entity parameters frozenset({'user_id', 'agent_id'}) are not supported in search(). Use filters={'user_id': '...'} instead."}]}

# %%
# Ask the agent a question
response = memory_agent("What are the events happening in the New York today?")
print(response)

# %%
# List all stored memories
print("All Stored Memories:")
all_memories = memory_agent.tool.mem0_memory(
    action="list", user_id=USER_ID
)
# Out:
# All Stored Memories:
# Model us.anthropic.claude-sonnet-4-5-20250929-v1:0 may not be available in region us-east-1
# ╭─────────────────────────────────────────── ❌ Memory Operation Error ───────────────────────────────────────────╮
# │ Top-level entity parameters frozenset({'user_id', 'agent_id'}) are not supported in get_all(). Use              │
# │ filters={'user_id': '...'} instead.                                                                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Interactive Agent Usage
#
# Finally, we provide an interactive loop for users to interact with the memory agent. Users can store new memories, retrieve existing ones, or list all stored memories.
#
# To test interactive usage:
# 1. Install the requirements: `pip install -r requirements.txt`
# 1. Run the python file `personal_agent_with_memory.py`.

# %% [markdown]
# ## Conclusion
#
# This notebook demonstrates how to create a personal agent with memory capabilities using the Strands framework. The agent can:
#
# 1. Store information about the user
# 2. Retrieve relevant memories based on context
# 3. Search the web for additional information
# 4. Provide personalized responses
#
# By combining these capabilities, the agent can maintain context across conversations and provide more personalized assistance over time.

# %% [markdown]
# ### Cleanup
#
# Run this bash script to clean up the Opensearch Serverless resources. You don't need to run this if you used the "MEM0_PLATFORM_API".

# %%
# !sh prereqs/cleanup_OSS.sh
# Out:
# Removing Opensearch Serverless resources ...
# Configuration loaded: {'opensearch_collection_name': 'memory-store', 'opensearch_description': 'Memory vector store'}
# Deleting OpenSearch Serverless collection: memory-store
# Found collection ID: rz3mgj4qysnv92mzofzl
# Collection memory-store deleted successfully!
# Waiting for collection deletion to complete...
# Access policy memory-store-ap-1777142691 deleted successfully!
# Network policy memory-store-np-1777142691 deleted successfully!
# Encryption policy memory-store-sp-1777142691 deleted successfully!
# OpenSearch Serverless resources cleanup completed!
# Deleted SSM parameter: memory-store-hostname
# Deleted SSM parameter: memory-store-id
# Deleted SSM parameter: memory-store-arn
# Deleted SSM parameter: memory-store-name
# Deleted SSM parameter: memory-store-encryption_policy
# Deleted SSM parameter: memory-store-network_policy
# Deleted SSM parameter: memory-store-access_policy
# Removed .env file: /mnt/strands_agents_samples/python/01-learn/06-memory/.env
